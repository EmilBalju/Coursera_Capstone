# %% [markdown]
# #  Agrupación y Segmentación de Vecindarios en la Ciudad de Toronto

# %% [markdown]
# ## Librerias a Emplear

# %%
import numpy as np # librería para manejar datos vectorizados

import pandas as pd # librería para análisis de datos
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # librería para manejar archivos JSON 

#!conda install -c conda-forge geopy --yes # retirar el comentario de esta línea si no ha completado el laboratorio de la API de FourSquare 
from geopy.geocoders import Nominatim # convertir una dirección en valores de latitud y longitud

import requests # librería para manejar solicitudes
from pandas.io.json import json_normalize # librería para convertir un archivo json en un dataframe pandas

# Matplotlib y módulos asociados para graficar
import matplotlib.cm as cm
import matplotlib.colors as colors

# importar k-means desde la fase de agrupación
from sklearn.cluster import KMeans

#!conda install -c conda-forge folium=0.5.0 --yes # retirar el comentario de esta línea si no ha completado el laboratorio de la API de FourSquare
import folium # librería para graficar mapas 

print('Libraries imported.')
# Out:
# Libraries imported.

# %%
from bs4 import BeautifulSoup
import matplotlib.cm as cm
import matplotlib.colors as colors

# %% [markdown]
# ## Lectura de Datos a Emplear

# %%
url = 'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'
req = requests.get(url)
soup = BeautifulSoup(req.content, "html.parser")

# %%
tabla = soup.find('table')

# %%
tabla_final = []

for i in range(0,9):
    for j in tabla.find_all('tr'):
        cols = j.find_all('p')
        tabla_final.append(cols[i].getText())

# %%
df = pd.DataFrame(tabla_final)
df.head()
# Out:
#                                                    0
# 0                                  M1ANot assigned\n
# 1                  M1BScarborough(Malvern / Rouge)\n
# 2  M1CScarborough(Rouge Hill / Port Union / Highl...
# 3  M1EScarborough(Guildwood / Morningside / West ...
# 4                           M1GScarborough(Woburn)\n

# %% [markdown]
# Le damos un formato a la tabla, para obtener la tabla solicitada

# %%
df['Postal Code'] = df[0].str[0:3]
df["Borough"]=df[0].str[3:].str.split("(",n=1,expand=True)[0]
df["Neigh"]=df[0].str.rsplit("(",n=2,expand=True)[1].str.split(")",n=1,expand=True)[0]
df["Neighborhood"]=df["Neigh"].str.replace(" / ",",")

# %%
df.head()
# Out:
#                                                    0 Postal Code  \
# 0                                  M1ANot assigned\n         M1A
# 1                  M1BScarborough(Malvern / Rouge)\n         M1B
# 2  M1CScarborough(Rouge Hill / Port Union / Highl...         M1C
# 3  M1EScarborough(Guildwood / Morningside / West ...         M1E
# 4                           M1GScarborough(Woburn)\n         M1G
#
#           Borough                                     Neigh  \
# 0  Not assigned\n                                      None
# 1     Scarborough                           Malvern / Rouge
# 2     Scarborough  Rouge Hill / Port Union / Highland Creek
# 3     Scarborough       Guildwood / Morningside / West Hill
# 4     Scarborough                                    Woburn
#
#                            Neighborhood
# 0                                  None
# 1                         Malvern,Rouge
# 2  Rouge Hill,Port Union,Highland Creek
# 3       Guildwood,Morningside,West Hill
# 4                                Woburn

# %%
df_final=df[(df["Borough"]!="Not assigned\n")]
df_final=df_final.drop([0,"Neigh"],axis=1)

# %%
df_final
# Out:
#     Postal Code                                            Borough  \
# 1           M1B                                        Scarborough
# 2           M1C                                        Scarborough
# 3           M1E                                        Scarborough
# 4           M1G                                        Scarborough
# 5           M1H                                        Scarborough
# 6           M1J                                        Scarborough
# 7           M1K                                        Scarborough
# 8           M1L                                        Scarborough
# 9           M1M                                        Scarborough
# 10          M1N                                        Scarborough
# 11          M1P                                        Scarborough
# 12          M1R                                        Scarborough
# 13          M1S                                        Scarborough
# 14          M1T                                        Scarborough
# 15          M1V                                        Scarborough
# 16          M1W                                        Scarborough
# 17          M1X                                        Scarborough
# 25          M2H                                         North York
# 26          M2J                                         North York
# 27          M2K                                         North York
# 28          M2L                                         North York
# 29          M2M                                         North York
# 30          M2N                                         North York
# 31          M2P                                         North York
# 32          M2R                                         North York
# 40          M3A                                         North York
# 41          M3B                                         North York
# 42          M3C                                         North York
# 45          M3H                                         North York
# 46          M3J                                         North York
# 47          M3K                                         North York
# 48          M3L                                         North York
# 49          M3M                                         North York
# 50          M3N                                         North York
# 60          M4A                                         North York
# 61          M4B                                          East York
# 62          M4C                                          East York
# 63          M4E                                       East Toronto
# 64          M4G                                          East York
# 65          M4H                                          East York
# 66          M4J                              East YorkEast Toronto
# 67          M4K                                       East Toronto
# 68          M4L                                       East Toronto
# 69          M4M                                       East Toronto
# 70          M4N                                    Central Toronto
# 71          M4P                                    Central Toronto
# 72          M4R                                    Central Toronto
# 73          M4S                                    Central Toronto
# 74          M4T                                    Central Toronto
# 75          M4V                                    Central Toronto
# 76          M4W                                   Downtown Toronto
# 77          M4X                                   Downtown Toronto
# 78          M4Y                                   Downtown Toronto
# 80          M5A                                   Downtown Toronto
# 81          M5B                                   Downtown Toronto
# 82          M5C                                   Downtown Toronto
# 83          M5E                                   Downtown Toronto
# 84          M5G                                   Downtown Toronto
# 85          M5H                                   Downtown Toronto
# 86          M5J                                   Downtown Toronto
# 87          M5K                                   Downtown Toronto
# 88          M5L                                   Downtown Toronto
# 89          M5M                                         North York
# 90          M5N                                    Central Toronto
# 91          M5P                                    Central Toronto
# 92          M5R                                    Central Toronto
# 93          M5S                                   Downtown Toronto
# 94          M5T                                   Downtown Toronto
# 95          M5V                                   Downtown Toronto
# 96          M5W     Downtown TorontoStn A PO Boxes25 The Esplanade
# 97          M5X                                   Downtown Toronto
# 100         M6A                                         North York
# 101         M6B                                         North York
# 102         M6C                                               York
# 103         M6E                                               York
# 104         M6G                                   Downtown Toronto
# 105         M6H                                       West Toronto
# 106         M6J                                       West Toronto
# 107         M6K                                       West Toronto
# 108         M6L                                         North York
# 109         M6M                                               York
# 110         M6N                                               York
# 111         M6P                                       West Toronto
# 112         M6R                                       West Toronto
# 113         M6S                                       West Toronto
# 120         M7A                                       Queen's Park
# 132         M7R   MississaugaCanada Post Gateway Processing Centre
# 138         M7Y  East TorontoBusiness reply mail Processing Cen...
# 155         M8V                                          Etobicoke
# 156         M8W                                          Etobicoke
# 157         M8X                                          Etobicoke
# 158         M8Y                                          Etobicoke
# 159         M8Z                                          Etobicoke
# 160         M9A                                          Etobicoke
# 161         M9B                                          Etobicoke
# 162         M9C                                          Etobicoke
# 168         M9L                                         North York
# 169         M9M                                         North York
# 170         M9N                                               York
# 171         M9P                                          Etobicoke
# 172         M9R                                          Etobicoke
# 175         M9V                                          Etobicoke
# 176         M9W                                 EtobicokeNorthwest
#
#                                           Neighborhood
# 1                                        Malvern,Rouge
# 2                 Rouge Hill,Port Union,Highland Creek
# 3                      Guildwood,Morningside,West Hill
# 4                                               Woburn
# 5                                            Cedarbrae
# 6                                  Scarborough Village
# 7            Kennedy Park,Ionview,East Birchmount Park
# 8                        Golden Mile,Clairlea,Oakridge
# 9        Cliffside,Cliffcrest,Scarborough Village West
# 10                          Birch Cliff,Cliffside West
# 11   Dorset Park,Wexford Heights,Scarborough Town C...
# 12                                    Wexford,Maryvale
# 13                                           Agincourt
# 14               Clarks Corners,Tam O'Shanter,Sullivan
# 15   Milliken,Agincourt North,Steeles East,L'Amorea...
# 16                        Steeles West,L'Amoreaux West
# 17                                         Upper Rouge
# 25                                   Hillcrest Village
# 26                          Fairview,Henry Farm,Oriole
# 27                                     Bayview Village
# 28                             York Mills,Silver Hills
# 29                              Willowdale,Newtonbrook
# 30                                          Willowdale
# 31                                     York Mills West
# 32                                          Willowdale
# 40                                           Parkwoods
# 41                                           Don Mills
# 42                                           Don Mills
# 45       Bathurst Manor,Wilson Heights,Downsview North
# 46                      Northwood Park,York University
# 47                                           Downsview
# 48                                           Downsview
# 49                                           Downsview
# 50                                           Downsview
# 60                                    Victoria Village
# 61                      Parkview Hill,Woodbine Gardens
# 62                                    Woodbine Heights
# 63                                         The Beaches
# 64                                             Leaside
# 65                                    Thorncliffe Park
# 66                                  The Danforth  East
# 67                         The Danforth West,Riverdale
# 68                       India Bazaar,The Beaches West
# 69                                     Studio District
# 70                                       Lawrence Park
# 71                                    Davisville North
# 72                                  North Toronto West
# 73                                          Davisville
# 74                          Moore Park,Summerhill East
# 75   Summerhill West,Rathnelly,South Hill,Forest Hi...
# 76                                            Rosedale
# 77                          St. James Town,Cabbagetown
# 78                                Church and Wellesley
# 80                            Regent Park,Harbourfront
# 81                            Garden District, Ryerson
# 82                                      St. James Town
# 83                                         Berczy Park
# 84                                  Central Bay Street
# 85                              Richmond,Adelaide,King
# 86     Harbourfront East,Union Station,Toronto Islands
# 87             Toronto Dominion Centre,Design Exchange
# 88                       Commerce Court,Victoria Hotel
# 89                    Bedford Park,Lawrence Manor East
# 90                                            Roselawn
# 91                            Forest Hill North & West
# 92                   The Annex,North Midtown,Yorkville
# 93                       University of Toronto,Harbord
# 94             Kensington Market,Chinatown,Grange Park
# 95   CN Tower,King and Spadina,Railway Lands,Harbou...
# 96                                      Enclave of M5E
# 97               First Canadian Place,Underground city
# 100                    Lawrence Manor,Lawrence Heights
# 101                                          Glencairn
# 102                                 Humewood-Cedarvale
# 103                                Caledonia-Fairbanks
# 104                                           Christie
# 105                        Dufferin,Dovercourt Village
# 106                            Little Portugal,Trinity
# 107         Brockton,Parkdale Village,Exhibition Place
# 108             North Park,Maple Leaf Park,Upwood Park
# 109     Del Ray,Mount Dennis,Keelsdale and Silverthorn
# 110                       Runnymede,The Junction North
# 111                       High Park,The Junction South
# 112                              Parkdale,Roncesvalles
# 113                                  Runnymede,Swansea
# 120                      Ontario Provincial Government
# 132                                     Enclave of L4W
# 138                                     Enclave of M4L
# 155         New Toronto,Mimico South,Humber Bay Shores
# 156                              Alderwood,Long Branch
# 157        The Kingsway,Montgomery Road,Old Mill North
# 158  Old Mill South,King's Mill Park,Sunnylea,Humbe...
# 159  Mimico NW,The Queensway West,South of Bloor,Ki...
# 160                                   Islington Avenue
# 161  West Deane Park,Princess Gardens,Martin Grove,...
# 162  Eringate,Bloordale Gardens,Old Burnhamthorpe,M...
# 168                                      Humber Summit
# 169                                    Humberlea,Emery
# 170                                             Weston
# 171                                          Westmount
# 172  Kingsview Village,St. Phillips,Martin Grove Ga...
# 175  South Steeles,Silverstone,Humbergate,Jamestown...
# 176  Clairville,Humberwood,Woodbine Downs,West Humb...

# %%
df_final.shape
# Out:
# (103, 3)

# %% [markdown]
# ## Obtención de las coordenadas de Latitud y Longitud

# %%
file_name ='https://cocl.us/Geospatial_data'
Geoconder = pd.read_csv(file_name)

# %%
neighborhoods=pd.merge(df_final,Geoconder,on="Postal Code")

# %%
neighborhoods.head()
# Out:
#   Postal Code      Borough                          Neighborhood   Latitude  \
# 0         M1B  Scarborough                         Malvern,Rouge  43.806686
# 1         M1C  Scarborough  Rouge Hill,Port Union,Highland Creek  43.784535
# 2         M1E  Scarborough       Guildwood,Morningside,West Hill  43.763573
# 3         M1G  Scarborough                                Woburn  43.770992
# 4         M1H  Scarborough                             Cedarbrae  43.773136
#
#    Longitude
# 0 -79.194353
# 1 -79.160497
# 2 -79.188711
# 3 -79.216917
# 4 -79.239476

# %%
type(neighborhoods)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ### Observamos cuantos barrios unicos hay en Toronto

# %%
print('There are {} uniques Borough.'.format(len(neighborhoods['Borough'].unique())))
# Out:
# There are 15 uniques Borough.

# %%
neighborhoods['Borough'].unique()
# Out:
# array(['Scarborough', 'North York', 'East York', 'East Toronto',
#        'East YorkEast Toronto', 'Central Toronto', 'Downtown Toronto',
#        'Downtown TorontoStn A PO Boxes25 The Esplanade', 'York',
#        'West Toronto', "Queen's Park",
#        'MississaugaCanada Post Gateway Processing Centre',
#        'East TorontoBusiness reply mail Processing Centre969 Eastern',
#        'Etobicoke', 'EtobicokeNorthwest'], dtype=object)

# %% [markdown]
# ## Agrupación y segmentación de los vecindarios

# %% [markdown]
# #### Utilice la librería geopy para obtener la latitud y la longitud de la Ciudad de Toronto

# %% [markdown]
# Para poder definir una instancia del geocoder necesitaremos definir un user_agent. Nombraremos a nuestro agente ny_explorer, como se muestra a continuación.

# %%
neighborhoods = neighborhoods[neighborhoods['Borough'].str.contains('Toronto')].reset_index(drop=True)
neighborhoods.groupby("Borough").size().sort_values(ascending=False)
# Out:
# Borough
# Downtown Toronto                                                17
# Central Toronto                                                  9
# West Toronto                                                     6
# East Toronto                                                     4
# East YorkEast Toronto                                            1
# East TorontoBusiness reply mail Processing Centre969 Eastern     1
# Downtown TorontoStn A PO Boxes25 The Esplanade                   1
# dtype: int64

# %%
address = 'TORONTO,CA'

geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Toronto are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Toronto are 43.6534817, -79.3839347.

# %% [markdown]
# ### Genere un mapa de Toronto con los barrios super puestos por encima.

# %%
# crear un mapa de Nueva York utilizando los valores de latitud y longitud
map_Toronto = folium.Map(location=[latitude, longitude], zoom_start=10)

# añadir marcadores al mapa
for lat, lng, borough, neighborhood in zip(neighborhoods['Latitude'], neighborhoods['Longitude'], neighborhoods['Borough'], neighborhoods['Neighborhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_Toronto)  
    
map_Toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script&gt;L_PREFER_CANVAS = false; L_NO_TOUCH = false; L_DISABLE_3D = false;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.2.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.2.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://rawgit.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css&quot;/&gt;
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#
#             &lt;style&gt; #map_bc1eea0c7894870efe75779b58d3bd2f {
#                 position : relative;
#                 width : 100.0%;
#                 height: 100.0%;
#                 left: 0.0%;
#                 top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bc1eea0c7894870efe75779b58d3bd2f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#
#
#                 var bounds = null;
#
#
#             var map_bc1eea0c7894870efe75779b58d3bd2f = L.map(
#                                   &#x27;map_bc1eea0c7894870efe75779b58d3bd2f&#x27;,
#                                   {center: [43.6534817,-79.3839347],
#                                   zoom: 10,
#                                   maxBounds: bounds,
#                                   layers: [],
#                                   worldCopyJump: false,
#                                   crs: L.CRS.EPSG3857
#                                  });
#
#
#
#             var tile_layer_086f8889297680546b0c751a0944d2bc = L.tileLayer(
#                 &#x27;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&#x27;,
#                 {
#   &quot;attribution&quot;: null,
#   &quot;detectRetina&quot;: false,
#   &quot;maxZoom&quot;: 18,
#   &quot;minZoom&quot;: 1,
#   &quot;noWrap&quot;: false,
#   &quot;subdomains&quot;: &quot;abc&quot;
# }
#                 ).addTo(map_bc1eea0c7894870efe75779b58d3bd2f);
#
#
#             var circle_marker_23dacd817d7f87d42b45e3842df2d677 = L.circleMarker(
#                 [43.67635739999999,-79.2930312],
#                 {
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;color&quot;: &quot;blue&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3186cc&quot;,
#   &quot;fillOpacity&quot;: 0.7,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;opacity&quot;: 1.0,
#   &quot;radius&quot;: 5,
#   &quot;stroke&quot;: true,
#   &quot;weight&quot;: 3
# }
#                 ).addTo(map_bc1eea0c7894870efe75779b58d3bd2f);
#
#
#             var popup_9807362cdeaa22d9c927e086a8bc423e = L.popup({maxWidth: &#x27;300&#x27;});
#
#
#                 var html_59b2861cb66d1c0907effc9d84340145 = $(&#x27;&lt;div id=&quot;html_59b2861cb66d1c0907effc9d84340145&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;The Beaches, East Toronto&lt;/div&gt;&#x27;)[0];
#                 popup_9807362cdeaa22d9c927e086a8bc423e.setContent(html_59b2861cb66d1c0907effc9d84340145);
#
#
#             circle_marker_23dacd817d7f87d42b45e3842df2d677.bindPopup(popup_9807362cdeaa22d9c927e086a8bc423e);
#
#
#
#
#             var circle_marker_644e91ead9c1dd5bf78a24bc4349da9b = L.circleMarker(
#                 [43.685347,-79.3381065],
#                 {
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;color&quot;: &quot;blue&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3186cc&quot;,
#   &quot;fillOpacity&quot;: 0.7,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;opacity&quot;: 1.0,
#   &quot;radius&quot;: 5,
#   &quot;stroke&quot;: true,
#   &quot;weight&quot;: 3
# }
#                 ).addTo(map_bc1eea0c7894870efe75779b58d3bd2f);
#
#
#             var popup_8ccb4833f1d03d54471f6b1efc74b6c1 = L.popup({maxWidth: &#x27;300&#x27;});
#
#
#                 var html_f98f9d058c2d18cc0fb2967206c6a305 = $(&#x27;&lt;div id=&quot;html_f98f9d058c2d18cc0fb2967206c6a305&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;The Danforth  East, East YorkEast Toronto&lt;/div&gt;&#x27;)[0];
#                 popup_8ccb4833f1d03d54471f6b1efc74b6c1.setContent(html_f98f9d058c2d18cc0fb2967206c6a305);
#
#
#             circle_marker_644e91ead9c1dd5bf78a24bc4349da9b.bindPopup(popup_8ccb4833f1d03d54471f6b1efc74b6c1);
#
#
#
#
#             var circle_marker_05e509456782b9fc0817972c767352dc = L.circleMarker(
#                 [43.6795571,-79.352188],
#                 {
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;color&quot;: &quot;blue&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3186cc&quot;,
#   &quot;fillOpacity&quot;: 0.7,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;opacity&quot;: 1.0,
#   &quot;radius&quot;: 5,
#   &quot;stroke&quot;: true,
#   &quot;weight&quot;: 3
# }
#                 ).addTo(map_bc1eea0c7894870efe75779b58d3bd2f);
#
#
#             var popup_d010f5be378df448cc482976605747cc = L.popup({maxWidth: &#x27;300&#x27;});
#
#
#                 var html_752f0b1004223229c506a77d61fdc38b = $(&#x27;&lt;div id=&quot;html_752f0b1004223229c506a77d61fdc38b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;The Danforth West,Riverdale, East Toronto&lt;/div&gt;&#x27;)[0];
#                 popup_d010f5be378df448cc482976605747cc.setContent(html_752f0b1004223229c506a77d61fdc38b);
#
#
#             circle_marker_05e509456782b9fc0817972c767352dc.bindPopup(popup_d010f5be378df448cc482976605747cc);
#
#
#
#
#             var circle_marker_bed84af1aad76e3909e94ba02a660fdd = L.circleMarker(
#                 [43.6689985,-79.31557159999998],
#                 {
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;color&quot;: &quot;blue&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3186cc&quot;,
#   &quot;fillOpacity&quot;: 0.7,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;opacity&quot;: 1.0,

# %% [markdown]
# ## Explorar Barrios en Toronto

# %%
neighborhood_latitude = neighborhoods.loc[0, 'Latitude'] # latitud del barrio 
neighborhood_longitude = neighborhoods.loc[0, 'Longitude'] # longitud del barrio

neighborhood_name = neighborhoods.loc[0, 'Neighborhood'] # nombre del barrio

print('Latitude and longitude values of {} are {}, {}.'.format(neighborhood_name, 
                                                               neighborhood_latitude, 
                                                               neighborhood_longitude))
# Out:
# Latitude and longitude values of The Beaches are 43.67635739999999, -79.2930312.

# %%
headers = {
        'Accept': 'application/json',
        'Authorization': 'fsq3z8M+K9/afb++fE1PLmG6xOKTPAj/SsruzHI0bYoklOk='
    }
url = 'https://api.foursquare.com/v3/places/search?ll={},{}&radius={}&limit={}'
url = url.format(neighborhood_latitude,neighborhood_longitude, 500, 50)
url
# Out:
# 'https://api.foursquare.com/v3/places/search?ll=43.67635739999999,-79.2930312&radius=500&limit=50'

# %%
results = requests.get(url,headers = headers).json()
results
# Out:
# {'results': [{'fsq_id': '4bd461bc77b29c74a07d9282',
#    'categories': [{'id': 16019,
#      'name': 'Hiking Trail',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/hikingtrail_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 89,
#    'geocodes': {'main': {'latitude': 43.676676, 'longitude': -79.294126},
#     'roof': {'latitude': 43.676676, 'longitude': -79.294126}},
#    'link': '/v3/places/4bd461bc77b29c74a07d9282',
#    'location': {'country': 'CA',
#     'cross_street': 'Queen St.',
#     'formatted_address': 'Queen St., Toronto ON',
#     'locality': 'Toronto',
#     'region': 'ON'},
#    'name': 'Glen Manor Ravine',
#    'related_places': {},
#    'timezone': 'America/Toronto'},
#   {'fsq_id': '4dbc8fe96a23e294ba3237bd',
#    'categories': [{'id': 16032,
#      'name': 'Park',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 176,
#    'geocodes': {'main': {'latitude': 43.674403, 'longitude': -79.294516},
#     'roof': {'latitude': 43.674403, 'longitude': -79.294516}},
#    'link': '/v3/places/4dbc8fe96a23e294ba3237bd',
#    'location': {'address': '131 Glen Manor Dr',
#     'country': 'CA',
#     'cross_street': '',
#     'formatted_address': '131 Glen Manor Dr, Toronto ON',
#     'locality': 'Toronto',
#     'region': 'ON'},
#    'name': 'Glen Stewart Park',
#    'related_places': {},
#    'timezone': 'America/Toronto'},
#   {'fsq_id': '0bb2d5a345d02032b733f0b6',
#    'categories': [{'id': 11006,
#      'name': 'Audiovisual Service',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/default_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 117,
#    'geocodes': {'main': {'latitude': 43.676932, 'longitude': -79.294256}},
#    'link': '/v3/places/0bb2d5a345d02032b733f0b6',
#    'location': {'address': '4 Jim Wilson Lane',
#     'country': 'CA',
#     'formatted_address': '4 Jim Wilson Lane, Toronto ON M4E 0C1',
#     'locality': 'Toronto',
#     'postcode': 'M4E 0C1',
#     'region': 'ON'},
#    'name': 'Santon Audio',
#    'related_places': {}},
#   {'fsq_id': '4b9c6e76c8ea40047bca6aa7',
#    'categories': [{'id': 11041,
#      'name': 'Film Studio',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/movietheater_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 221,
#    'geocodes': {'main': {'latitude': 43.67578, 'longitude': -79.295668},
#     'roof': {'latitude': 43.67578, 'longitude': -79.295668}},
#    'link': '/v3/places/4b9c6e76c8ea40047bca6aa7',
#    'location': {'address': '15 Beaufort Rd',
#     'country': 'CA',
#     'formatted_address': '15 Beaufort Rd, Toronto ON M4E 1M6',
#     'locality': 'Toronto',
#     'postcode': 'M4E 1M6',
#     'region': 'ON'},
#    'name': 'Verite Films Inc',
#    'related_places': {}},
#   {'fsq_id': '4ad4c062f964a52011f820e3',
#    'categories': [{'id': 17069,
#      'name': 'Grocery Store / Supermarket',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 470,
#    'geocodes': {'main': {'latitude': 43.678841, 'longitude': -79.2976},
#     'roof': {'latitude': 43.678841, 'longitude': -79.2976}},
#    'link': '/v3/places/4ad4c062f964a52011f820e3',
#    'location': {'address': '125 Southwood Dr',
#     'country': 'CA',
#     'formatted_address': '125 Southwood Dr, Toronto ON M4E 0B8',
#     'locality': 'Toronto',
#     'postcode': 'M4E 0B8',
#     'region': 'ON'},
#    'name': 'The Big Carrot Beach Community Market',
#    'related_places': {'children': [{'fsq_id': '4bd1db4e046076b0f1a57271',
#       'name': 'The Big Carrot Organic Juice Bar'}]},
#    'timezone': 'America/Toronto'},
#   {'fsq_id': '4ebfbda0d70e4ac50f6e5f58',
#    'categories': [{'id': 18025,
#      'name': 'Dance Studio',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/performingarts_dancestudio_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 262,
#    'geocodes': {'main': {'latitude': 43.677386, 'longitude': -79.295968},
#     'roof': {'latitude': 43.677386, 'longitude': -79.295968}},
#    'link': '/v3/places/4ebfbda0d70e4ac50f6e5f58',
#    'location': {'address': '29 Cavendish St',
#     'country': 'CA',
#     'formatted_address': '29 Cavendish St, Toronto ON M4E 1N9',
#     'locality': 'Toronto',
#     'neighborhood': ['The Beach'],
#     'postcode': 'M4E 1N9',
#     'region': 'ON'},
#    'name': 'Coysh School of Dance',
#    'related_places': {}},
#   {'fsq_id': '4c0a537d340720a1702b8693',
#    'categories': [{'id': 16037,
#      'name': 'Playground',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/playground_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 391,
#    'geocodes': {'main': {'latitude': 43.674716, 'longitude': -79.297338}},
#    'link': '/v3/places/4c0a537d340720a1702b8693',
#    'location': {'address': '24 Williamson Rd',
#     'country': 'CA',
#     'cross_street': 'Wineva ave',
#     'formatted_address': '24 Williamson Rd (Wineva ave), Toronto ON M4E 1K5',
#     'locality': 'Toronto',
#     'postcode': 'M4E 1K5',
#     'region': 'ON'},
#    'name': 'Williamson Road Playground',
#    'related_places': {},
#    'timezone': 'America/Toronto'},
#   {'fsq_id': '3243cc1354a440790b9e0a0c',
#    'categories': [{'id': 11001,
#      'name': 'Advertising Agency',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#       'suffix': '.png'}},
#     {'id': 17112,
#      'name': 'Print Store',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/default_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 292,
#    'geocodes': {'main': {'latitude': 43.677602, 'longitude': -79.289828},
#     'roof': {'latitude': 43.677602, 'longitude': -79.289828}},
#    'link': '/v3/places/3243cc1354a440790b9e0a0c',
#    'location': {'address': '272 Beech Ave',
#     'country': 'CA',
#     'formatted_address': '272 Beech Ave, Toronto ON M4E 3J2',
#     'locality': 'Toronto',
#     'neighborhood': ['East York'],
#     'postcode': 'M4E 3J2',
#     'region': 'ON'},
#    'name': 'Airflow Signs Inc',
#    'related_places': {}},
#   {'fsq_id': '5ea88bfaa7a46800077a492c',
#    'categories': [{'id': 13032,
#      'name': 'Cafes, Coffee, and Tea Houses',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#       'suffix': '.png'}},
#     {'id': 13065,
#      'name': 'Restaurant',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#       'suffix': '.png'}}],
#    'chains': [{'id': 'd5719cc0-d890-0132-61d3-7a163eb2a6fc',
#      'name': 'Tim Hortons'}],
#    'distance': 478,
#    'geocodes': {'main': {'latitude': 43.678684, 'longitude': -79.29823},
#     'roof': {'latitude': 43.678684, 'longitude': -79.29823}},
#    'link': '/v3/places/5ea88bfaa7a46800077a492c',
#    'location': {'address': '637 Kingston Rd',
#     'country': 'CA',
#     'cross_street': '',
#     'formatted_address': '637 Kingston Rd, Toronto ON M4E 1R3',
#     'locality': 'Toronto',
#     'postcode': 'M4E 1R3',
#     'region': 'ON'},
#    'name': 'Tim Hortons',
#    'related_places': {},
#    'timezone': 'America/Toronto'},
#   {'fsq_id': 'd5f4cb5f48b3420f5c2fedd8',
#    'categories': [],
#    'chains': [],
#    'distance': 311,
#    'geocodes': {'main': {'latitude': 43.678419, 'longitude': -79.295662},
#     'roof': {'latitude': 43.678419, 'longitude': -79.295662}},
#    'link': '/v3/places/d5f4cb5f48b3420f5c2fedd8',
#    'location': {'address': '31 Glen Stewart Ave',
#     'country': 'CA',
#     'formatted_address': '31 Glen Stewart Ave, Toronto ON M4E 1P6',
#     'locality': 'Toronto',
#     'postcode': 'M4E 1P6',
#     'region': 'ON'},
#    'name': 'Christopher Lawson Photography',
#    'related_places': {}},
#   {'fsq_id': '6033062e8b7a4f843e850279',
#    'categories': [{'id': 17043,
#      'name': 'Clothing Store',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/apparel_',
#       'suffix': '.png'}},
#     {'id': 17046,
#      'name': 'Lingerie Store',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/apparel_lingerie_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 317,
#    'geocodes': {'main': {'latitude': 43.674184, 'longitude': -79.290463}},
#    'link': '/v3/places/6033062e8b7a4f843e850279',
#    'location': {'address': '95 Balsam Ave',
#     'country': 'CA',
#     'formatted_address': '95 Balsam Ave, Toronto ON M4E 3B8',
#     'locality': 'Toronto',
#     'postcode': 'M4E 3B8',
#     'region': 'ON'},
#    'name': 'Rubies Bras',
#    'related_places': {}},
#   {'fsq_id': 'a9db4c8bd34941e85b05ece8',
#    'categories': [{'id': 11020,
#      'name': 'Business and Strategy Consulting Office',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 320,
#    'geocodes': {'main': {'latitude': 43.6758, 'longitude': -79.289124},
#     'roof': {'latitude': 43.6758, 'longitude': -79.289124}},
#    'link': '/v3/places/a9db4c8bd34941e85b05ece8',
#    'location': {'address': '200 Beech Ave',
#     'country': 'CA',
#     'formatted_address': '200 Beech Ave, Toronto ON M4E 3H9',
#     'locality': 'Toronto',
#     'neighborhood': ['East York'],
#     'postcode': 'M4E 3H9',
#     'region': 'ON'},
#    'name': 'Scott Burns Planning',
#    'related_places': {}},
#   {'fsq_id': '4b8daea1f964a520480833e3',
#    'categories': [{'id': 13018,
#      'name': 'Pub',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#       'suffix': '.png'}},
#     {'id': 13049,
#      'name': 'Diner',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/diner_',
#       'suffix': '.png'}},
#     {'id': 13068,
#      'name': 'American Restaurant',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 459,
#    'geocodes': {'main': {'latitude': 43.67926, 'longitude': -79.297245},
#     'roof': {'latitude': 43.67926, 'longitude': -79.297245}},
#    'link': '/v3/places/4b8daea1f964a520480833e3',
#    'location': {'address': '676 Kingston Rd',
#     'country': 'CA',
#     'cross_street': 'at Main St.',
#     'formatted_address': '676 Kingston Rd (at Main St.), Toronto ON M4E 1R4',
#     'locality': 'Toronto',
#     'neighborhood': ['East York'],
#     'postcode': 'M4E 1R4',
#     'region': 'ON'},
#    'name': 'The Grover Pub & Grub',
#    'related_places': {},
#    'timezone': 'America/Toronto'},
#   {'fsq_id': '8b94c7e754ec4abdf2ce5c23',
#    'categories': [{'id': 11148,
#      'name': 'Property Management Office',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/realestate_',
#       'suffix': '.png'}},
#     {'id': 11149,
#      'name': 'Real Estate Agency',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/realestate_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 327,
#    'geocodes': {'main': {'latitude': 43.677955, 'longitude': -79.289603},
#     'roof': {'latitude': 43.677955, 'longitude': -79.289603}},
#    'link': '/v3/places/8b94c7e754ec4abdf2ce5c23',
#    'location': {'address': '281 Beech Ave',
#     'country': 'CA',
#     'formatted_address': '281 Beech Ave, Toronto ON M4E 3J1',
#     'locality': 'Toronto',
#     'postcode': 'M4E 3J1',
#     'region': 'ON'},
#    'name': 'Harding & King Real Estate Services Inc Brokerage',
#    'related_places': {}},
#   {'fsq_id': '0ada0bde03774d2be764bffd',
#    'categories': [],
#    'chains': [],
#    'distance': 331,
#    'geocodes': {'main': {'latitude': 43.674395, 'longitude': -79.289932},
#     'roof': {'latitude': 43.674395, 'longitude': -79.289932}},
#    'link': '/v3/places/0ada0bde03774d2be764bffd',
#    'location': {'address': '78 Spruce Hill Rd',
#     'country': 'CA',
#     'formatted_address': '78 Spruce Hill Rd, Toronto ON',
#     'locality': 'Toronto',
#     'region': 'ON'},
#    'name': 'Inside Out Staging and Design',
#    'related_places': {}},
#   {'fsq_id': '6bc5af07bb18468f7ea62a8c',
#    'categories': [{'id': 12082,
#      'name': 'Organization',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 342,
#    'geocodes': {'main': {'latitude': 43.678745, 'longitude': -79.290335},
#     'roof': {'latitude': 43.678745, 'longitude': -79.290335}},
#    'link': '/v3/places/6bc5af07bb18468f7ea62a8c',
#    'location': {'address': '300 Beech Ave',
#     'country': 'CA',
#     'formatted_address': '300 Beech Ave, Toronto ON M4E 3J2',
#     'locality': 'Toronto',
#     'neighborhood': ['East York'],
#     'postcode': 'M4E 3J2',
#     'region': 'ON'},
#    'name': 'Gleeson Management Associates Inc',
#    'related_places': {}},
#   {'fsq_id': 'b8a623e5228b4010eab9a192',
#    'categories': [],
#    'chains': [],
#    'distance': 357,
#    'geocodes': {'main': {'latitude': 43.679012, 'longitude': -79.290517},
#     'roof': {'latitude': 43.679012, 'longitude': -79.290517}},
#    'link': '/v3/places/b8a623e5228b4010eab9a192',
#    'location': {'address': '193 Balsam Ave',
#     'address_extended': '# 1',
#     'country': 'CA',
#     'formatted_address': '193 Balsam Ave, Toronto ON M4E 3C2',
#     'locality': 'Toronto',
#     'neighborhood': ['East York'],
#     'postcode': 'M4E 3C2',
#     'region': 'ON'},
#    'name': 'Kathite Industries Inc',
#    'related_places': {}},
#   {'fsq_id': '5c19617c92e7a9002c36c676',
#    'categories': [{'id': 11090,
#      'name': 'Interior Designer',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/realestate_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 476,
#    'geocodes': {'main': {'latitude': 43.680403, 'longitude': -79.290689},
#     'roof': {'latitude': 43.680403, 'longitude': -79.290689}},
#    'link': '/v3/places/5c19617c92e7a9002c36c676',
#    'location': {'address': '874 Kingston Rd',
#     'country': 'CA',
#     'cross_street': 'Beech Ave',
#     'formatted_address': '874 Kingston Rd (Beech Ave), Toronto ON M4E 1S3',
#     'locality': 'Toronto',
#     'postcode': 'M4E 1S3',
#     'region': 'ON'},
#    'name': 'Skaut Design',
#    'related_places': {},
#    'timezone': 'America/Toronto'},
#   {'fsq_id': '613f90740af76429d486bc7e',
#    'categories': [{'id': 13034,
#      'name': 'Café',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 484,
#    'geocodes': {'main': {'latitude': 43.680372, 'longitude': -79.290508}},
#    'link': '/v3/places/613f90740af76429d486bc7e',
#    'location': {'address': '878 Kingston Rd',
#     'country': 'CA',
#     'cross_street': '',
#     'formatted_address': '878 Kingston Rd, Toronto ON M4E 1S3',
#     'locality': 'Toronto',
#     'postcode': 'M4E 1S3',
#     'region': 'ON'},
#    'name': 'Black Dog Baking Co Inc',
#    'related_places': {},
#    'timezone': 'America/Toronto'},
#   {'fsq_id': '50b53e5ee4b0305cc3ebdfdb',
#    'categories': [{'id': 17020,
#      'name': 'Boutique',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/apparel_boutique_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 487,
#    'geocodes': {'main': {'latitude': 43.680449, 'longitude': -79.290836},
#     'roof': {'latitude': 43.680449, 'longitude': -79.290836}},
#    'link': '/v3/places/50b53e5ee4b0305cc3ebdfdb',
#    'location': {'address': '870 Kingston',
#     'country': 'CA',
#     'cross_street': '',
#     'formatted_address': '870 Kingston, Toronto ON',
#     'locality': 'Toronto',
#     'region': 'ON'},
#    'name': 'Crazy Sexy Cool',
#    'related_places': {},
#    'timezone': 'America/Toronto'},
#   {'fsq_id': '50f19e46e4b0e31be3c5a8d0',
#    'categories': [{'id': 18025,
#      'name': 'Dance Studio',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/performingarts_dancestudio_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 491,
#    'geocodes': {'main': {'latitude': 43.680481, 'longitude': -79.291169},
#     'roof': {'latitude': 43.680481, 'longitude': -79.291169}},
#    'link': '/v3/places/50f19e46e4b0e31be3c5a8d0',
#    'location': {'address': '1A Hannaford St',
#     'country': 'CA',
#     'cross_street': 'Kingston Road',
#     'formatted_address': '1A Hannaford St (Kingston Road), Toronto ON M4E 3G6',
#     'locality': 'Toronto',
#     'neighborhood': ['East York'],
#     'postcode': 'M4E 3G6',
#     'region': 'ON'},
#    'name': 'Beaches Dance & Music Studio',
#    'related_places': {},
#    'timezone': 'America/Toronto'},
#   {'fsq_id': '5c0ef0401543c7002c1131e3',
#    'categories': [{'id': 13031,
#      'name': 'Burger Joint',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/burger_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 494,
#    'geocodes': {'main': {'latitude': 43.680417, 'longitude': -79.290504},
#     'roof': {'latitude': 43.680417, 'longitude': -79.290504}},
#    'link': '/v3/places/5c0ef0401543c7002c1131e3',
#    'location': {'address': '884 Kingston Rd',
#     'country': 'CA',
#     'cross_street': '',
#     'formatted_address': '884 Kingston Rd, Toronto ON M4E 1S3',
#     'locality': 'Toronto',
#     'neighborhood': ['East Toronto'],
#     'postcode': 'M4E 1S3',
#     'region': 'ON'},
#    'name': 'Fearless Meat',
#    'related_places': {},
#    'timezone': 'America/Toronto'},
#   {'fsq_id': '5d7167b59e5cec0008811dfc',
#    'categories': [{'id': 11064,
#      'name': 'Hair Salon',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/salon_barber_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 498,
#    'geocodes': {'main': {'latitude': 43.678613, 'longitude': -79.298339}},
#    'link': '/v3/places/5d7167b59e5cec0008811dfc',
#    'location': {'address': '623 Kingston Rd',
#     'country': 'CA',
#     'cross_street': 'Main St',
#     'formatted_address': '623 Kingston Rd (Main St), Toronto ON M4E 1R3',
#     'locality': 'Toronto',
#     'postcode': 'M4E 1R3',
#     'region': 'ON'},
#    'name': 'The Curl Lounge',
#    'related_places': {},
#    'timezone': 'America/Toronto'},
#   {'fsq_id': '62b2b3a926064bfdf00b4ed3',
#    'categories': [{'id': 11094,
#      'name': 'Painter',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/realestate_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 379,
#    'geocodes': {'main': {'latitude': 43.678941, 'longitude': -79.289945},
#     'roof': {'latitude': 43.678941, 'longitude': -79.289945}},
#    'link': '/v3/places/62b2b3a926064bfdf00b4ed3',
#    'location': {'address': '310 Beech Ave',
#     'country': 'CA',
#     'formatted_address': '310 Beech Ave, Toronto ON M4E 3H6',
#     'locality': 'Toronto',
#     'postcode': 'M4E 3H6',
#     'region': 'ON'},
#    'name': 'Bluebird Painting',
#    'related_places': {}},
#   {'fsq_id': '4ba3fda9f964a5201a7538e3',
#    'categories': [{'id': 11064,
#      'name': 'Hair Salon',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/salon_barber_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 504,
#    'geocodes': {'main': {'latitude': 43.68041, 'longitude': -79.290596},
#     'roof': {'latitude': 43.68041, 'longitude': -79.290596}},
#    'link': '/v3/places/4ba3fda9f964a5201a7538e3',
#    'location': {'address': '1015 Kingston Rd',
#     'country': 'CA',
#     'cross_street': 'Kingston Rd. & Victoria Park Ave.',
#     'formatted_address': '1015 Kingston Rd (Kingston Rd. & Victoria Park Ave.), Toronto ON M4E 1T3',
#     'locality': 'Toronto',
#     'neighborhood': ['East York'],
#     'postcode': 'M4E 1T3',
#     'region': 'ON'},
#    'name': 'Iron Butterfly',
#    'related_places': {},
#    'timezone': 'America/Toronto'},
#   {'fsq_id': '510ace3b1648bb726853baa4',
#    'categories': [{'id': 17082,
#      'name': 'Furniture and Home Store',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/furniture_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 511,
#    'geocodes': {'main': {'latitude': 43.672199, 'longitude': -79.290803},
#     'roof': {'latitude': 43.672199, 'longitude': -79.290803}},
#    'link': '/v3/places/510ace3b1648bb726853baa4',
#    'location': {'address': '2180 Queen St E',
#     'country': 'CA',
#     'cross_street': 'Maclean & Queen',
#     'formatted_address': '2180 Queen St E (Maclean & Queen), Toronto ON M4E 1E6',
#     'locality': 'Toronto',
#     'postcode': 'M4E 1E6',
#     'region': 'ON'},
#    'name': 'Essentia at the Beach',
#    'related_places': {},
#    'timezone': 'America/Toronto'},
#   {'fsq_id': 'a748eb7f2e2546ad26a0eafa',
#    'categories': [{'id': 11090,
#      'name': 'Interior Designer',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/realestate_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 394,
#    'geocodes': {'main': {'latitude': 43.676265, 'longitude': -79.288121},
#     'roof': {'latitude': 43.676265, 'longitude': -79.288121}},
#    'link': '/v3/places/a748eb7f2e2546ad26a0eafa',
#    'location': {'address': '25 Pine Ave',
#     'country': 'CA',
#     'formatted_address': '25 Pine Ave, Toronto ON',
#     'locality': 'Toronto',
#     'region': 'ON'},
#    'name': 'Studio 8 Design',
#    'related_places': {}},
#   {'fsq_id': '4c153eecb7b9c928afa5ac37',
#    'categories': [{'id': 16032,
#      'name': 'Park',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 522,
#    'geocodes': {'main': {'latitude': 43.672465, 'longitude': -79.292575},
#     'roof': {'latitude': 43.672465, 'longitude': -79.292575}},
#    'link': '/v3/places/4c153eecb7b9c928afa5ac37',
#    'location': {'address': '131 Glen Manor Dr',
#     'country': 'CA',
#     'cross_street': '',
#     'formatted_address': '131 Glen Manor Dr, Toronto ON',
#     'locality': 'Toronto',
#     'neighborhood': ['East York'],
#     'region': 'ON'},
#    'name': 'Ivan Forrest Gardens',
#    'related_places': {},
#    'timezone': 'America/Toronto'},
#   {'fsq_id': '3638802d9af040de2ee2694d',
#    'categories': [{'id': 11107,
#      'name': 'Insurance Agency',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/financial_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 416,
#    'geocodes': {'main': {'latitude': 43.678518, 'longitude': -79.288802},
#     'roof': {'latitude': 43.678518, 'longitude': -79.288802}},
#    'link': '/v3/places/3638802d9af040de2ee2694d',
#    'location': {'address': '280 Willow Ave',
#     'address_extended': '# 1A',
#     'country': 'CA',
#     'formatted_address': '280 Willow Ave, Toronto ON M4E 3K7',
#     'locality': 'Toronto',
#     'neighborhood': ['East York'],
#     'postcode': 'M4E 3K7',
#     'region': 'ON'},
#    'name': 'Managed Disability Resources',
#    'related_places': {}},
#   {'fsq_id': 'f986c468dfef4d2ed123f02f',
#    'categories': [{'id': 12082,
#      'name': 'Organization',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 419,
#    'geocodes': {'main': {'latitude': 43.673834, 'longitude': -79.289142},
#     'roof': {'latitude': 43.673834, 'longitude': -79.289142}},
#    'link': '/v3/places/f986c468dfef4d2ed123f02f',
#    'location': {'address': '47 Spruce Hill Rd',
#     'country': 'CA',
#     'formatted_address': '47 Spruce Hill Rd, Toronto ON',
#     'locality': 'Toronto',
#     'region': 'ON'},
#    'name': 'Psychodramatic Bodywork',
#    'related_places': {}},
#   {'fsq_id': 'f4f4d428c36b4cad8fe68e8c',
#    'categories': [{'id': 11027,
#      'name': 'Computer Repair Service',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/default_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 429,
#    'geocodes': {'main': {'latitude': 43.679509, 'longitude': -79.296115},
#     'roof': {'latitude': 43.679509, 'longitude': -79.296115}},
#    'link': '/v3/places/f4f4d428c36b4cad8fe68e8c',
#    'location': {'address': '710 Kingston Rd',
#     'country': 'CA',
#     'formatted_address': '710 Kingston Rd, Toronto ON M4E 1R7',
#     'locality': 'Toronto',
#     'neighborhood': ['East York'],
#     'postcode': 'M4E 1R7',
#     'region': 'ON'},
#    'name': 'Med E-Care Healthcare Software Inc',
#    'related_places': {}},
#   {'fsq_id': '32a67410aa0e4e55f9c7b9bf',
#    'categories': [{'id': 11134,
#      'name': 'Pet Grooming Service',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pet_store_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 432,
#    'geocodes': {'main': {'latitude': 43.679568, 'longitude': -79.296077},
#     'roof': {'latitude': 43.679568, 'longitude': -79.296077}},
#    'link': '/v3/places/32a67410aa0e4e55f9c7b9bf',
#    'location': {'address': '706 Kingston Rd',
#     'country': 'CA',
#     'formatted_address': '706 Kingston Rd, Toronto ON',
#     'locality': 'Toronto',
#     'region': 'ON'},
#    'name': 'Metro Hound',
#    'related_places': {}},
#   {'fsq_id': '01098e5a383a1fa153dac185',
#    'categories': [{'id': 11090,
#      'name': 'Interior Designer',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/realestate_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 437,
#    'geocodes': {'main': {'latitude': 43.68004, 'longitude': -79.291112}},
#    'link': '/v3/places/01098e5a383a1fa153dac185',
#    'location': {'address': '849 Kingston Rd',
#     'country': 'CA',
#     'formatted_address': '849 Kingston Rd, Toronto ON',
#     'locality': 'Toronto',
#     'region': 'ON'},
#    'name': 'TEB Interiors Inc',
#    'related_places': {}},
#   {'fsq_id': '6227fc27d5c84f2e28dc6281',
#    'categories': [{'id': 13000,
#      'name': 'Dining and Drinking',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 451,
#    'geocodes': {'main': {'latitude': 43.680109, 'longitude': -79.290877},
#     'roof': {'latitude': 43.680109, 'longitude': -79.290877}},
#    'link': '/v3/places/6227fc27d5c84f2e28dc6281',
#    'location': {'address': '862 Kingston Rd',
#     'country': 'CA',
#     'formatted_address': '862 Kingston Rd, Toronto ON M4E 1S3',
#     'locality': 'Toronto',
#     'neighborhood': ['East End Danforth'],
#     'postcode': 'M4E 1S3',
#     'region': 'ON'},
#    'name': 'Matrix Cyber Cafe',
#    'related_places': {}},
#   {'fsq_id': '5c8e06816549477a87e0a19c',
#    'categories': [{'id': 11079,
#      'name': 'Carpet and Flooring Contractor',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/realestate_',
#       'suffix': '.png'}},
#     {'id': 11086,
#      'name': 'General Contractor',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/realestate_',
#       'suffix': '.png'}},
#     {'id': 11091,
#      'name': 'Kitchen Remodeler',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/realestate_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 459,
#    'geocodes': {'main': {'latitude': 43.680344, 'longitude': -79.291522},
#     'roof': {'latitude': 43.680344, 'longitude': -79.291522}},
#    'link': '/v3/places/5c8e06816549477a87e0a19c',
#    'location': {'address': '848 Kingston Rd',
#     'country': 'CA',
#     'formatted_address': '848 Kingston Rd, Toronto ON M4E 1S1',
#     'locality': 'Toronto',
#     'neighborhood': ['East York'],
#     'postcode': 'M4E 1S1',
#     'region': 'ON'},
#    'name': 'Reno Man',
#    'related_places': {}},
#   {'fsq_id': 'a1a8bde1a4e64786d554df88',
#    'categories': [{'id': 17046,
#      'name': 'Lingerie Store',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/apparel_lingerie_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 461,
#    'geocodes': {'main': {'latitude': 43.680347, 'longitude': -79.294609},
#     'roof': {'latitude': 43.680347, 'longitude': -79.294609}},
#    'link': '/v3/places/a1a8bde1a4e64786d554df88',
#    'location': {'address': '200 Bay St',
#     'country': 'CA',
#     'formatted_address': '200 Bay St, Toronto ON',
#     'locality': 'Toronto',
#     'region': 'ON'},
#    'name': 'La Senza - Toronto',
#    'related_places': {}},
#   {'fsq_id': '9d39076f1f1344b78ee50edf',
#    'categories': [{'id': 11086,
#      'name': 'General Contractor',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/realestate_',
#       'suffix': '.png'}},
#     {'id': 11098,
#      'name': 'Roofer',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/realestate_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 465,
#    'geocodes': {'main': {'latitude': 43.679201, 'longitude': -79.297282},
#     'roof': {'latitude': 43.679201, 'longitude': -79.297282}},
#    'link': '/v3/places/9d39076f1f1344b78ee50edf',
#    'location': {'address': 'Kingston Rd',
#     'country': 'CA',
#     'formatted_address': 'Kingston Rd, Toronto ON M4E 1V6',
#     'locality': 'Toronto',
#     'postcode': 'M4E 1V6',
#     'region': 'ON'},
#    'name': 'Sky Limitless Roofing',
#    'related_places': {}},
#   {'fsq_id': '6afbe7156a8d4a5706f5defd',
#    'categories': [{'id': 11138,
#      'name': 'Photographer',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/default_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 467,
#    'geocodes': {'main': {'latitude': 43.679384, 'longitude': -79.297077},
#     'roof': {'latitude': 43.679384, 'longitude': -79.297077}},
#    'link': '/v3/places/6afbe7156a8d4a5706f5defd',
#    'location': {'address': '674 Kingston Rd',
#     'country': 'CA',
#     'formatted_address': '674 Kingston Rd, Toronto ON',
#     'locality': 'Toronto',
#     'region': 'ON'},
#    'name': 'KT Photography',
#    'related_places': {}},
#   {'fsq_id': '5e9633912b72450bcaf80769',
#    'categories': [{'id': 12096,
#      'name': 'Senior Citizen Service',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/default_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 467,
#    'geocodes': {'main': {'latitude': 43.67926, 'longitude': -79.297245},
#     'roof': {'latitude': 43.67926, 'longitude': -79.297245}},
#    'link': '/v3/places/5e9633912b72450bcaf80769',
#    'location': {'address': '680 Kingston Rd',
#     'country': 'CA',
#     'formatted_address': '680 Kingston Rd, Toronto ON M4E 3V9',
#     'locality': 'Toronto',
#     'neighborhood': ['East York'],
#     'postcode': 'M4E 3V9',
#     'region': 'ON'},
#    'name': 'Senior Link',
#    'related_places': {}},
#   {'fsq_id': '2ca5c5e36314430bbd07a20f',
#    'categories': [{'id': 11090,
#      'name': 'Interior Designer',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/realestate_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 472,
#    'geocodes': {'main': {'latitude': 43.673113, 'longitude': -79.296839},
#     'roof': {'latitude': 43.673113, 'longitude': -79.296839}},
#    'link': '/v3/places/2ca5c5e36314430bbd07a20f',
#    'location': {'address': '210 Wineva Ave',
#     'country': 'CA',
#     'formatted_address': '210 Wineva Ave, Toronto ON M4E 2T4',
#     'locality': 'Toronto',
#     'postcode': 'M4E 2T4',
#     'region': 'ON'},
#    'name': 'Taylor Judith',
#    'related_places': {}},
#   {'fsq_id': '3612a8beaff64376a1a060c0',
#    'categories': [{'id': 17035,
#      'name': 'Drugstore',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pharmacy_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 477,
#    'geocodes': {'main': {'latitude': 43.680383, 'longitude': -79.290966},
#     'roof': {'latitude': 43.680383, 'longitude': -79.290966}},
#    'link': '/v3/places/3612a8beaff64376a1a060c0',
#    'location': {'address': '855 Kingston Rd',
#     'country': 'CA',
#     'formatted_address': '855 Kingston Rd, Toronto ON M4E 1R9',
#     'locality': 'Toronto',
#     'neighborhood': ['East York'],
#     'postcode': 'M4E 1R9',
#     'region': 'ON'},
#    'name': 'Beech Medical Pharmacy',
#    'related_places': {}},
#   {'fsq_id': '322c3209798e4455d2657161',
#    'categories': [],
#    'chains': [],
#    'distance': 481,
#    'geocodes': {'main': {'latitude': 43.680436, 'longitude': -79.291021},
#     'roof': {'latitude': 43.680436, 'longitude': -79.291021}},
#    'link': '/v3/places/322c3209798e4455d2657161',
#    'location': {'address': '2366 Kingston Rd',
#     'country': 'CA',
#     'formatted_address': '2366 Kingston Rd, Toronto ON M1N 1V2',
#     'locality': 'Toronto',
#     'postcode': 'M1N 1V2',
#     'region': 'ON'},
#    'name': 'Celestial Stain Glass Li Inc',
#    'related_places': {}},
#   {'fsq_id': '4eda825951a64c77b88351d7',
#    'categories': [{'id': 17138,
#      'name': 'Vintage and Thrift Store',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/default_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 487,
#    'geocodes': {'main': {'latitude': 43.680358, 'longitude': -79.290541},
#     'roof': {'latitude': 43.680358, 'longitude': -79.290541}},
#    'link': '/v3/places/4eda825951a64c77b88351d7',
#    'location': {'address': '872 Kingston Rd',
#     'country': 'CA',
#     'formatted_address': '872 Kingston Rd, Toronto ON M4E 1S3',
#     'locality': 'Toronto',
#     'neighborhood': ['East York'],
#     'postcode': 'M4E 1S3',
#     'region': 'ON'},
#    'name': 'V I C S Resale Centre',
#    'related_places': {}},
#   {'fsq_id': '77cf93870105497750796d56',
#    'categories': [{'id': 11064,
#      'name': 'Hair Salon',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/salon_barber_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 491,
#    'geocodes': {'main': {'latitude': 43.68041, 'longitude': -79.290596},
#     'roof': {'latitude': 43.68041, 'longitude': -79.290596}},
#    'link': '/v3/places/77cf93870105497750796d56',
#    'location': {'address': '878 Kingston Rd',
#     'country': 'CA',
#     'formatted_address': '878 Kingston Rd, Toronto ON M4E 1S3',
#     'locality': 'Toronto',
#     'postcode': 'M4E 1S3',
#     'region': 'ON'},
#    'name': 'Savvi Salo & Spray Tanning',
#    'related_places': {}},
#   {'fsq_id': 'e578c6dd9f0f4ed395a4ab9a',
#    'categories': [],
#    'chains': [],
#    'distance': 491,
#    'geocodes': {'main': {'latitude': 43.68041, 'longitude': -79.290596},
#     'roof': {'latitude': 43.68041, 'longitude': -79.290596}},
#    'link': '/v3/places/e578c6dd9f0f4ed395a4ab9a',
#    'location': {'address': '872 Kingston Rd',
#     'country': 'CA',
#     'formatted_address': '872 Kingston Rd, Toronto ON M4E 1S3',
#     'locality': 'Toronto',
#     'postcode': 'M4E 1S3',
#     'region': 'ON'},
#    'name': 'Eaune Natural Skin Care Studio',
#    'related_places': {}},
#   {'fsq_id': 'fb5f27200a0d413086228657',
#    'categories': [{'id': 11149,
#      'name': 'Real Estate Agency',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/realestate_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 497,
#    'geocodes': {'main': {'latitude': 43.672048, 'longitude': -79.29134},
#     'roof': {'latitude': 43.672048, 'longitude': -79.29134}},
#    'link': '/v3/places/fb5f27200a0d413086228657',
#    'location': {'address': '2156 Queen St E',
#     'country': 'CA',
#     'formatted_address': '2156 Queen St E, Toronto ON',
#     'locality': 'Toronto',
#     'region': 'ON'},
#    'name': 'Wineva Realty Inc',
#    'related_places': {}},
#   {'fsq_id': '2c156462fdaa4e0db2a8915d',
#    'categories': [{'id': 11070,
#      'name': 'Massage Clinic',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/spa_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 498,
#    'geocodes': {'main': {'latitude': 43.680469, 'longitude': -79.290559},
#     'roof': {'latitude': 43.680469, 'longitude': -79.290559}},
#    'link': '/v3/places/2c156462fdaa4e0db2a8915d',
#    'location': {'address': '882 Kingston Rd',
#     'country': 'CA',
#     'formatted_address': '882 Kingston Rd, Toronto ON M4E 1S3',
#     'locality': 'Toronto',
#     'postcode': 'M4E 1S3',
#     'region': 'ON'},
#    'name': 'Kate Wylie Rmt',
#    'related_places': {}},
#   {'fsq_id': 'c4627d606839441f40df88c8',
#    'categories': [],
#    'chains': [],
#    'distance': 499,
#    'geocodes': {'main': {'latitude': 43.671963, 'longitude': -79.291748},
#     'roof': {'latitude': 43.671963, 'longitude': -79.291748}},
#    'link': '/v3/places/c4627d606839441f40df88c8',
#    'location': {'address': '2300 Young St',
#     'country': 'CA',
#     'formatted_address': '2300 Young St, Toronto ON M4E 1E4',
#     'locality': 'Toronto',
#     'postcode': 'M4E 1E4',
#     'region': 'ON'},
#    'name': 'Sawari Inc',
#    'related_places': {}},
#   {'fsq_id': '4dbae3bcffcbcd485662c0cd',
#    'categories': [{'id': 10004,
#      'name': 'Art Gallery',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/artgallery_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 648,
#    'geocodes': {'main': {'latitude': 43.680403, 'longitude': -79.290689},
#     'roof': {'latitude': 43.680403, 'longitude': -79.290689}},
#    'link': '/v3/places/4dbae3bcffcbcd485662c0cd',
#    'location': {'address': '870A Kingston Rd',
#     'country': 'CA',
#     'formatted_address': '870A Kingston Rd, Toronto ON M4E 1S3',
#     'locality': 'Toronto',
#     'neighborhood': ['East York'],
#     'postcode': 'M4E 1S3',
#     'region': 'ON'},
#    'name': 'Cobalt Gallery & Clay Studio',
#    'related_places': {},
#    'timezone': 'America/Toronto'}],
#  'context': {'geo_bounds': {'circle': {'center': {'latitude': 43.67635739999999,
#      'longitude': -79.2930312},
#     'radius': 500}}}}

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500,limit=5):

    URL='https://api.foursquare.com/v3/places/search?ll={},{}&radius={}&limit={}'
    headers = {
        'Accept': 'application/json',
        'Authorization': 'fsq3z8M+K9/afb++fE1PLmG6xOKTPAj/SsruzHI0bYoklOk='
    }
    df_list=[]
    
    for name, lat, lng in zip(names, latitudes, longitudes):
        url = URL.format(lat, lng, radius, limit)
        results = requests.get(url,headers = headers).json()
        
        for each_result in results['results']: # filter the result based on JSON identification
            result={}
            result['Neighborhood']=name
            result['Neighborhood Latitude']=lat
            result['Neighborhood Longitude']=lng
            result['Name']=each_result['name']
            result['Venue Latitude']=each_result['geocodes']['main']['latitude']
            result['Venue Longitude']=each_result['geocodes']['main']['longitude']
            result['Locality']=each_result['location']['locality']
            result['Category_Names']=each_result['categories'][0]['name']
            df_list.append(result.copy())
    return pd.DataFrame(df_list)

# %% [markdown]
# #### Ahora ejecutamos la función anterior para cada categoria y creamos un nuevo dataframe llamado Toronto_venues

# %%
Toronto_venues = getNearbyVenues(names=neighborhoods['Neighborhood'],
                                   latitudes=neighborhoods['Latitude'],
                                   longitudes=neighborhoods['Longitude'])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-170-c345257c054f> in <module>
#       1 Toronto_venues = getNearbyVenues(names=neighborhoods['Neighborhood'],
#       2                                    latitudes=neighborhoods['Latitude'],
# ----> 3                                    longitudes=neighborhoods['Longitude'])
#
# <ipython-input-169-8457d229e542> in getNearbyVenues(names, latitudes, longitudes, radius, limit)
#      21             result['Venue Longitude']=each_result['geocodes']['main']['longitude']
#      22             result['Locality']=each_result['location']['locality']
# ---> 23             result['Category_Names']=each_result['categories'][0]['name']
#      24             df_list.append(result.copy())
#      25     return pd.DataFrame(df_list)
#
# IndexError: list index out of range

# %% [markdown]
# #### Revisemos el tamaño del dataframe resultante

# %%
print(Toronto_venues.shape)
Toronto_venues.head()

# %% [markdown]
# Revisemos cuantos sitios se regresarón para cada barrio

# %%
Toronto_venues.groupby('Neighborhood').count()

# %% [markdown]
# Encontremos cuantas categorías únicas se pueden conservar de todos los sitios regresados

# %%
print('There are {} uniques categories.'.format(len(Toronto_venues['Category_Names'].unique())))

# %% [markdown]
# ## Analizar Cada Barrio

# %%
# codificación
Toronto_onehot = pd.get_dummies(Toronto_venues[['Category_Names']], prefix="", prefix_sep="")

# añadir la columna de barrio de regreso al dataframe
Toronto_onehot['Neighborhood'] = Toronto_venues['Neighborhood'] 

# mover la columna de barrio a la primer columna
fixed_columns = [Toronto_onehot.columns[-1]] + list(Toronto_onehot.columns[:-1])
Toronto_onehot = Toronto_onehot[fixed_columns]

Toronto_onehot.head()

# %% [markdown]
# Examinemos el tamaño del nuevo dataframe

# %%
Toronto_onehot.shape

# %% [markdown]
# #### Agrupemos las filas por barrios tomando la média de la frecuancia de la ocurrencia de cada categoría

# %%
Toronto_grouped = Toronto_onehot.groupby('Neighborhood').mean().reset_index()
Toronto_grouped

# %% [markdown]
# #### Confirmemos el nuevo tamaño

# %%
Toronto_grouped.shape

# %% [markdown]
# #### Imprimamos cada barrio junto con los 5 sitios mas comunes

# %%
num_top_venues = 5

for hood in Toronto_grouped['Neighborhood']:
    print("----"+hood+"----")
    temp = Toronto_grouped[Toronto_grouped['Neighborhood'] == hood].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_venues))
    print('\n')

# %% [markdown]
# #### Pongamos eso en el dataframe

# %% [markdown]
# Primero escribamos una función para ordenar los sitios en orden descendente.

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %% [markdown]
# Generemos el nuevo dataframe y mostremos los primeros 10 sitios de cada barrio.

# %%
num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# crear las columnas acorde al numero de sitios populares
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# crear un nuevo dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = Toronto_grouped['Neighborhood']

for ind in np.arange(Toronto_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(Toronto_grouped.iloc[ind, :], num_top_venues)

neighborhoods_venues_sorted.head()

# %% [markdown]
# ## 4. Barrios Agrupados

# %% [markdown]
# Ejecutemos k-means para agrupar los barrios en 5 agrupaciones.

# %%
# establecer el número de agrupaciones
kclusters = 5

Toronto_grouped_clustering = Toronto_grouped.drop('Neighborhood', 1)

# ejecutar k-means
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(Toronto_grouped_clustering)

# revisar las etiquetas de las agrupaciones generadas para cada fila del dataframe
kmeans.labels_[0:10]

# %% [markdown]
# Generemos un nuevo dataframe que incluya la agrupación asi como los 10 sitios mas populares de cada barrio.

# %%
# añadir etiquetas
neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

Toronto_merged = Toronto_data

# juntar manhattan_grouped con manhattan_data 
Toronto_merged = Toronto_merged.join(neighborhoods_venues_sorted.set_index('Neighborhood'), on='Neighborhood')

Toronto_merged.head() # revisar las ultimas columnas

# %% [markdown]
# Finalmente visualicemos las agrupaciones resultantes

# %%
# crear mapa
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# establecer el esquema de color para las agrupaciones
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# añadir marcadores al mapa
markers_colors = []
for lat, lon, poi, cluster in zip(Toronto_merged['Latitude'], Toronto_merged['Longitude'], Toronto_merged['Neighborhood'], Toronto_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters

# %% [markdown]
# ## Examinar Agrupaciones

# %% [markdown]
# Ahora puede examinar cada agrupación y determinar las categorias del sitio que distingue a cada agrupación. En base a las categorias definidas usted puede asignar un nombre a cada agrupación. Dejaré este ejercicio para usted.

# %% [markdown]
# #### Agrupación 1

# %%
Toronto_merged.loc[Toronto_merged['Cluster Labels'] == 0, Toronto_merged.columns[[1] + list(range(5, Toronto_merged.shape[1]))]]

# %% [markdown]
# #### Agrupación 2

# %%
Toronto_merged.loc[Toronto_merged['Cluster Labels'] == 1, Toronto_merged.columns[[1] + list(range(5, Toronto_merged.shape[1]))]]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-172-9aa80bb7f8e9> in <module>
# ----> 1 Toronto_merged.loc[Toronto_merged['Cluster Labels'] == 1, Toronto_merged.columns[[1] + list(range(5, Toronto_merged.shape[1]))]]
#
# NameError: name 'Toronto_merged' is not defined

# %% [markdown]
# ### Agrupación 3

# %%
Toronto_merged.loc[Toronto_merged['Cluster Labels'] == 2, Toronto_merged.columns[[1] + list(range(5, Toronto_merged.shape[1]))]]

# %% [markdown]
# ### Agrupación 4

# %%
Toronto_merged.loc[Toronto_merged['Cluster Labels'] == 3, Toronto_merged.columns[[1] + list(range(5, Toronto_merged.shape[1]))]]

# %% [markdown]
# ### Agrupación 5

# %%
Toronto_merged.loc[Toronto_merged['Cluster Labels'] == 4, Toronto_merged.columns[[1] + list(range(5, Toronto_merged.shape[1]))]]
